# %% [markdown]
# <a href="https://colab.research.google.com/github/Toto17515/Data_viz/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from datetime import  datetime
import matplotlib.pyplot as plt

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# #### ปี 2562

# %%
Data2562 = pd.read_excel('/content/gdrive/MyDrive/Data_Viz/Final/passenger-covid19.xlsx',sheet_name='Data62')
Data2562.head()
# Out:
#   ขนคน/ขนสินค้า โหมดการเดินทาง  ...   พ.ย. 2562   ธ.ค. 2562
# 0     ขนคน (คน)          ทางบก  ...   4559610.0   4840673.0
# 1     ขนคน (คน)          ทางบก  ...         NaN         NaN
# 2     ขนคน (คน)          ทางบก  ...   2450888.0   2516032.0
# 3    ขนคน (คัน)          ทางบก  ...  28325020.0  29615013.0
# 4    ขนคน (คัน)          ทางบก  ...  46996660.0  47294111.0
#
# [5 rows x 18 columns]

# %%
MoreData2562 = pd.read_excel('/content/gdrive/MyDrive/Data_Viz/Final/passenger-covid19.xlsx',sheet_name='2562', skiprows =1)
MoreData2562.head()
# Out:
#                Unnamed: 0  ม.ค. 2562  ...  พ.ย. 2562  ธ.ค. 2562
# 0             ทางถนน (คน)   69405563  ...   62158959   61473368
# 1             ทางราง (คน)   35935961  ...   39026128   37241766
# 2             ทางน้ำ (คน)    8074883  ...    8030502    8779130
# 3          ทางอากาศ* (คน)    3257864  ...    2926859    3093699
# 4  รวมประชาชนเดินทาง (คน)  116674271  ...  112142448  110587963
#
# [5 rows x 13 columns]

# %% [markdown]
# ####ปี 2563 - 2564

# %%
Data2563to2564 = pd.read_excel('/content/gdrive/MyDrive/Data_Viz/Final/passenger-covid19.xlsx',sheet_name='Data63-64')
Data2563to2564.head()
# Out:
#   ขนคน/ขนสินค้า โหมดการเดินทาง  ... 2021-04-25 00:00:00 2021-04-26 00:00:00
# 0     ขนคน (คน)          ทางบก  ...             27472.0             27701.0
# 1     ขนคน (คน)          ทางบก  ...                 NaN                 NaN
# 2     ขนคน (คน)          ทางบก  ...              6163.0              7849.0
# 3    ขนคน (คัน)          ทางบก  ...            800769.0            794328.0
# 4    ขนคน (คัน)          ทางบก  ...            900413.0            920383.0
#
# [5 rows x 488 columns]

# %%
MoreData2563to2564 = pd.read_excel('/content/gdrive/MyDrive/Data_Viz/Final/passenger-covid19.xlsx',sheet_name='2563-2564 รวมในประเทศ',skiprows=1)
MoreData2563to2564.head()
# Out:
#                Unnamed: 0  ... 2021-04-26 00:00:00
# 0             ทางถนน (คน)  ...              580580
# 1             ทางราง (คน)  ...              418835
# 2             ทางน้ำ (คน)  ...               53591
# 3          ทางอากาศ* (คน)  ...               13585
# 4  รวมประชาชนเดินทาง (คน)  ...             1066591
#
# [5 rows x 483 columns]

# %% [markdown]
# ### Covid-19 Data

# %%
data_covid = pd.read_csv("/content/gdrive/MyDrive/Data_Viz/Final/covid19cases.csv")
data_covid.head()
# Out:
#    No. announce_date  ... province_of_onset district_of_onset
# 0    1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1    2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2    3     22/1/2020  ...            นครปฐม             เมือง
# 3    4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4    5     24/1/2020  ...     กรุงเทพมหานคร               NaN
#
# [5 rows x 11 columns]

# %% [markdown]
# ข้อมูลภูมิภาคต่างๆที่แบ่งตามการท่องเที่ยว
#
# ![image.png](data:image/png;base64,...)
#
# อ้างอิง: https://th.wikipedia.org/wiki/%E0%B8%A0%E0%B8%B9%E0%B8%A1%E0%B8%B4%E0%B8%A0%E0%B8%B2%E0%B8%84%E0%B8%82%E0%B8%AD%E0%B8%87%E0%B8%9B%E0%B8%A3%E0%B8%B0%E0%B9%80%E0%B8%97%E0%B8%A8%E0%B9%84%E0%B8%97%E0%B8%A2https://th.wikipedia.org/wiki/%E0%B8%A0%E0%B8%B9%E0%B8%A1%E0%B8%B4%E0%B8%A0%E0%B8%B2%E0%B8%84%E0%B8%82%E0%B8%AD%E0%B8%87%E0%B8%9B%E0%B8%A3%E0%B8%B0%E0%B9%80%E0%B8%97%E0%B8%A8%E0%B9%84%E0%B8%97%E0%B8%A2

# %%
data_region= pd.read_csv("/content/gdrive/MyDrive/Data_Viz/Final/region.csv")
data_region.head()
# Out:
#         province              region
# 0         กระบี่                 ใต้
# 1  กรุงเทพมหานคร                กลาง
# 2      กาญจนบุรี                กลาง
# 3      กาฬสินธุ์  ตะวันออกเฉียงเหนือ
# 4      กำแพงเพชร               เหนือ

# %%
data_travel = MoreData2563to2564[MoreData2563to2564["Unnamed: 0"]=="รวมประชาชนเดินทาง (คน)"]
data_travel
# Out:
#                Unnamed: 0  ... 2021-04-26 00:00:00
# 4  รวมประชาชนเดินทาง (คน)  ...             1066591
#
# [1 rows x 483 columns]

# %%
data_total_travel = data_travel.transpose()
data_total_travel.head()
# Out:
#                     รวมประชาชนเดินทาง (คน)
# 2020-01-01 00:00:00                2743864
# 2020-01-02 00:00:00                3370836
# 2020-01-03 00:00:00                3520819
# 2020-01-04 00:00:00                2975450
# 2020-01-05 00:00:00                2835519

# %%
data_total_travel['date'] = data_total_travel.index
data_total_travel.head()
# Out:
#                     รวมประชาชนเดินทาง (คน)       date
# 2020-01-01 00:00:00                2743864 2020-01-01
# 2020-01-02 00:00:00                3370836 2020-01-02
# 2020-01-03 00:00:00                3520819 2020-01-03
# 2020-01-04 00:00:00                2975450 2020-01-04
# 2020-01-05 00:00:00                2835519 2020-01-05

# %%
data_total_travel.reset_index(drop=True, inplace=True)
data_total_travel.head()
# Out:
#   รวมประชาชนเดินทาง (คน)       date
# 0                2743864 2020-01-01
# 1                3370836 2020-01-02
# 2                3520819 2020-01-03
# 3                2975450 2020-01-04
# 4                2835519 2020-01-05

# %%
data_total_travel.rename(columns={"รวมประชาชนเดินทาง (คน)":"number_of_people"},inplace=True)
data_total_travel.head()
# Out:
#   number_of_people       date
# 0          2743864 2020-01-01
# 1          3370836 2020-01-02
# 2          3520819 2020-01-03
# 3          2975450 2020-01-04
# 4          2835519 2020-01-05

# %%
data_total_travel = data_total_travel[['date','number_of_people']]
data_total_travel.head()
# Out:
#         date number_of_people
# 0 2020-01-01          2743864
# 1 2020-01-02          3370836
# 2 2020-01-03          3520819
# 3 2020-01-04          2975450
# 4 2020-01-05          2835519

# %%
data_total_travel.set_index('date',inplace=True)
data_total_travel.head()
# Out:
#            number_of_people
# date
# 2020-01-01          2743864
# 2020-01-02          3370836
# 2020-01-03          3520819
# 2020-01-04          2975450
# 2020-01-05          2835519

# %%
data_total_travel_sum = data_total_travel.resample('1M').sum()
data_total_travel_sum.head()
# Out:
#             number_of_people
# date
# 2020-01-31         104516847
# 2020-02-29          92564306
# 2020-03-31          61635890
# 2020-04-30          22653390
# 2020-05-31          32569755

# %%
data_total_travel_sum.reset_index(drop=True, inplace=True)
data_total_travel_sum = data_total_travel_sum.rename_axis(None)  
data_total_travel_sum.head()
# Out:
#    number_of_people       date
# 0         104516847 2020-01-31
# 1          92564306 2020-02-29
# 2          61635890 2020-03-31
# 3          22653390 2020-04-30
# 4          32569755 2020-05-31

# %%
Data2563to2564.drop(['ขนคน/ขนสินค้า', 'รูปแบบการเดินทาง', 'สาธารณะ/ส่วนบุคคล', 'หน่วยงาน'], axis=1, inplace=True)
Data2563to2564.head()
# Out:
#   โหมดการเดินทาง  ... 2021-04-26 00:00:00
# 0          ทางบก  ...             27701.0
# 1          ทางบก  ...                 NaN
# 2          ทางบก  ...              7849.0
# 3          ทางบก  ...            794328.0
# 4          ทางบก  ...            920383.0
#
# [5 rows x 484 columns]

# %%
Data2563to2564_mode_T.dtypes
# Out:
# ทางบก               object
# ทางบก               object
# ทางบก               object
# ทางบก               object
# ทางบก               object
# ทางบก               object
# ทางบก               object
# ทางบก               object
# ทางบก               object
# ทางบก               object
# ทางบก               object
# ทางบก               object
# ทางบก               object
# ทางบก               object
# ทางบก               object
# ทางน้ำ              object
# ทางน้ำ              object
# ทางน้ำ              object
# ทางน้ำ              object
# ทางน้ำ              object
# ทางราง              object
# ทางราง              object
# ทางราง              object
# ทางราง              object
# ทางราง              object
# ทางอากาศ            object
# ทางอากาศ            object
# ทางอากาศ            object
# ทางอากาศ            object
# ทางถนน              object
# ทางถนน              object
# ทางราง              object
# ทางราง              object
# ทางน้ำ              object
# ทางน้ำ              object
# ทางอากาศ            object
# ทางอากาศ            object
# ทางอากาศ            object
# ทางอากาศ            object
# ทางอากาศ            object
# ทางอากาศ            object
# ทางอากาศ            object
# ทางอากาศ            object
# date        datetime64[ns]
# dtype: object

# %%
for i in range(Data2563to2564_mode_T.shape[0]):
  for j in range(Data2563to2564_mode_T.shape[1]):
    if type(Data2563to2564_mode_T.iloc[i,j]) == type('T'):
      Data2563to2564_mode_T.replace(to_replace = Data2563to2564_mode_T.iloc[i,j], value = 0.00, inplace=True)
Data2563to2564_mode_T.dtypes
# Out:
# ทางบก              float64
# ทางบก              float64
# ทางบก              float64
# ทางบก              float64
# ทางบก              float64
# ทางบก              float64
# ทางบก              float64
# ทางบก              float64
# ทางบก              float64
# ทางบก              float64
# ทางบก              float64
# ทางบก              float64
# ทางบก              float64
# ทางบก              float64
# ทางบก              float64
# ทางน้ำ             float64
# ทางน้ำ             float64
# ทางน้ำ             float64
# ทางน้ำ             float64
# ทางน้ำ             float64
# ทางราง             float64
# ทางราง             float64
# ทางราง             float64
# ทางราง             float64
# ทางราง             float64
# ทางอากาศ           float64
# ทางอากาศ           float64
# ทางอากาศ           float64
# ทางอากาศ           float64
# ทางถนน             float64
# ทางถนน             float64
# ทางราง             float64
# ทางราง             float64
# ทางน้ำ             float64
# ทางน้ำ             float64
# ทางอากาศ           float64
# ทางอากาศ           float64
# ทางอากาศ           float64
# ทางอากาศ           float64
# ทางอากาศ           float64
# ทางอากาศ           float64
# ทางอากาศ           float64
# ทางอากาศ           float64
# date        datetime64[ns]
# dtype: object

# %%
Data2563to2564_mode_T.fillna(0,inplace=True)

# %%
Data2563to2564_mode_T.set_index('date', inplace=True)
Data2563to2564_mode_T = Data2563to2564_mode_T.resample('1M').sum()
Data2563to2564_mode_T['date'] = Data2563to2564_mode_T.index
Data2563to2564_mode_T.reset_index(drop=True, inplace=True)
Data2563to2564_mode_T
# Out:
#         ทางบก  ทางบก     ทางบก  ...  ทางอากาศ  ทางอากาศ       date
# 0   5042527.0    0.0       0.0  ...   84888.0   90269.0 2020-01-31
# 1   4409362.0    0.0       0.0  ...   48332.0   55636.0 2020-02-29
# 2   3642962.0    0.0  271073.0  ...   20425.0   37668.0 2020-03-31
# 3     66321.0    0.0  120705.0  ...      59.0     105.0 2020-04-30
# 4    302528.0    0.0  378404.0  ...       0.0       0.0 2020-05-31
# 5   1203268.0    0.0  674903.0  ...       0.0       0.0 2020-06-30
# 6   2617337.0    0.0  829761.0  ...       0.0       0.0 2020-07-31
# 7   2300076.0    0.0  673394.0  ...       0.0       0.0 2020-08-31
# 8   2488630.0    0.0  650888.0  ...       0.0       0.0 2020-09-30
# 9   2559986.0    0.0  745696.0  ...       0.0       0.0 2020-10-31
# 10  2690461.0    0.0  692151.0  ...       0.0       0.0 2020-11-30
# 11  2742942.0    0.0  713638.0  ...       0.0       0.0 2020-12-31
# 12  1111522.0    0.0  339335.0  ...       0.0       0.0 2021-01-31
# 13  1157448.0    0.0  341052.0  ...       0.0       0.0 2021-02-28
# 14  1670827.0    0.0  420174.0  ...       0.0       0.0 2021-03-31
# 15  1477782.0    0.0  305552.0  ...       0.0       0.0 2021-04-30
#
# [16 rows x 44 columns]

# %%
Data2563to2564_mode_T_T['Mode'] = Data2563to2564_mode_T_T.index
Data2563to2564_mode_T_T = Data2563to2564_mode_T_T.groupby('Mode').sum()

# %%
df_travel_mode = Data2563to2564_mode
df_travel_mode.head()
# Out:
# Mode       date       ทางน้ำ        ทางบก       ทางราง     ทางอากาศ    ทางถนน
# 0    2020-01-31  8.26194e+06  2.15155e+08  4.19476e+07   1.0925e+07  51184656
# 1    2020-02-29  6.99893e+06  1.93693e+08  3.64606e+07  7.06299e+06  46429218
# 2    2020-03-31  2.55306e+06  1.73854e+08  2.44672e+07  3.60062e+06  32946721
# 3    2020-04-30  1.15716e+06  1.06936e+08  7.36872e+06        99878  14071816
# 4    2020-05-31  1.50509e+06  1.41717e+08  1.14829e+07       245770  19371815

# %%
data_covid_focus = data_covid[['No.', 'announce_date', 'province_of_onset']]
data_covid_focus.head()
# Out:
#    No. announce_date province_of_onset
# 0    1     12/1/2020     กรุงเทพมหานคร
# 1    2     17/1/2020     กรุงเทพมหานคร
# 2    3     22/1/2020            นครปฐม
# 3    4     22/1/2020     กรุงเทพมหานคร
# 4    5     24/1/2020     กรุงเทพมหานคร

# %%
fill_data_covid_focus = data_covid_focus.combine_first(fill_data_covide_province_of_isolation)

# %%
fill_data_covid_focus['announce_date'] = pd.to_datetime(fill_data_covid_focus['announce_date'], format='%d/%m/%Y',errors='coerce')
fill_data_covid_focus.head(1)
# Out:
#    No. announce_date province_of_onset
# 0    1    2020-01-12     กรุงเทพมหานคร

# %%
fill_data_covid_focus.isnull().sum()
# Out:
# No.                    0
# announce_date          0
# province_of_onset    377
# dtype: int64

# %%
data_covid_prvince = fill_data_covid_focus[['announce_date','province_of_onset']]
data_covid_prvince.head()
# Out:
#   announce_date province_of_onset
# 0    2020-01-12     กรุงเทพมหานคร
# 1    2020-01-17     กรุงเทพมหานคร
# 2    2020-01-22            นครปฐม
# 3    2020-01-22     กรุงเทพมหานคร
# 4    2020-01-24     กรุงเทพมหานคร

# %%
data_covid_prvince.dropna(inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_covid_number = fill_data_covid_focus[['announce_date']]
data_covid_number.head()
# Out:
#   announce_date
# 0    2020-01-12
# 1    2020-01-17
# 2    2020-01-22
# 3    2020-01-22
# 4    2020-01-24

# %%
data_covid_prvince['number_of_patients'] = 1
data_covid_prvince.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#   announce_date province_of_onset  number_of_patients
# 0    2020-01-12     กรุงเทพมหานคร                   1
# 1    2020-01-17     กรุงเทพมหานคร                   1
# 2    2020-01-22            นครปฐม                   1
# 3    2020-01-22     กรุงเทพมหานคร                   1
# 4    2020-01-24     กรุงเทพมหานคร                   1

# %%
data_covid_prvince_groupby = data_covid_prvince.groupby(['province_of_onset']).sum()
data_covid_prvince_groupby.head()
# Out:
#                    number_of_patients
# province_of_onset
# กระบี่                             78
# กรุงเทพมหานคร                   14611
# กาญจนบุรี                         103
# กาฬสินธุ์                          61
# กำแพงเพชร                          84

# %%
data_covid_prvince = data_covid_prvince_groupby[['province_of_onset','number_of_patients']]
data_covid_prvince.head()
# Out:
#   province_of_onset  number_of_patients
# 0            กระบี่                  78
# 1     กรุงเทพมหานคร               14611
# 2         กาญจนบุรี                 103
# 3         กาฬสินธุ์                  61
# 4         กำแพงเพชร                  84

# %%
data_covid_number['number_of_patients'] = 1
data_covid_number.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#   announce_date  number_of_patients
# 0    2020-01-12                   1
# 1    2020-01-17                   1
# 2    2020-01-22                   1
# 3    2020-01-22                   1
# 4    2020-01-24                   1

# %%
data_covid_number.set_index('announce_date', inplace=True)
data_covid_number.head()
# Out:
#                number_of_patients
# announce_date
# 2020-01-12                      1
# 2020-01-17                      1
# 2020-01-22                      1
# 2020-01-22                      1
# 2020-01-24                      1

# %%
data_covid_number_of_patients = data_covid_number.resample('1M').sum()
data_covid_number_of_patients
# Out:
#                number_of_patients
# announce_date
# 2020-01-31                     19
# 2020-02-29                     23
# 2020-03-31                   1609
# 2020-04-30                   1303
# 2020-05-31                    127
# 2020-06-30                     90
# 2020-07-31                    139
# 2020-08-31                    102
# 2020-09-30                    152
# 2020-10-31                    216
# 2020-11-30                    218
# 2020-12-31                   2886
# 2021-01-31                  11898
# 2021-02-28                   7169
# 2021-03-31                   2912
# 2021-04-30                  28647

# %%
data_covid_number_of_patients = data_covid_number_of_patients[['announce_date','number_of_patients']]
data_covid_number_of_patients.head()
# Out:
#   announce_date  number_of_patients
# 0    2020-01-31                  19
# 1    2020-02-29                  23
# 2    2020-03-31                1609
# 3    2020-04-30                1303
# 4    2020-05-31                 127

# %%
df_covid_patients = data_covid_number_of_patients
df_covid_patients.head()
# Out:
#   announce_date  number_of_patients
# 0    2020-01-31                  19
# 1    2020-02-29                  23
# 2    2020-03-31                1609
# 3    2020-04-30                1303
# 4    2020-05-31                 127

# %% [markdown]
# ###ข้อที่ 1

# %%
#ผู้ป่วย
df_covid_patients['percentage'] = df_covid_patients['number_of_patients']/df_covid_patients['number_of_patients'].sum()
df_covid_patients.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   announce_date  number_of_patients  percentage
# 0    2020-01-31                  19    0.000330
# 1    2020-02-29                  23    0.000400
# 2    2020-03-31                1609    0.027978
# 3    2020-04-30                1303    0.022657
# 4    2020-05-31                 127    0.002208

# %%
#การเดินทาง
df_total_travel['percentage'] = df_total_travel['number_of_people']/df_total_travel['number_of_people'].sum()
df_total_travel.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         date  number_of_people  Percentage  percentage
# 0 2020-01-31         104516847    0.110335    0.110335
# 1 2020-02-29          92564306    0.097717    0.097717
# 2 2020-03-31          61635890    0.065067    0.065067
# 3 2020-04-30          22653390    0.023915    0.023915
# 4 2020-05-31          32569755    0.034383    0.034383

# %%
plt.figure(figsize=(8, 8))
plt.plot(df_covid_patients['announce_date'],df_covid_patients['percentage'],'b',label = 'patient')
plt.plot(df_total_travel['date'],df_total_travel['percentage'],'r',label = 'travel')
plt.legend()
plt.xlabel("วันที่")
plt.ylabel("เปอร์เซ็น")
plt.title('กราฟเปรียบเทียบแนวโน้มจำนวนผู้ป่วยและจำนวนการเดินทาง')
# Out:
# Text(0.5, 1.0, 'กราฟเปรียบเทียบแนวโน้มจำนวนผู้ป่วยและจำนวนการเดินทาง')

# %% [markdown]
# ###ข้อที่ 2

# %%
#ข้อมูลจำนวนผู้ป่วย
df_covid_patients['percentage'] = df_covid_patients['number_of_patients']/df_covid_patients['number_of_patients'].sum()
df_covid_patients.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#   announce_date  number_of_patients  percentage
# 0    2020-01-31                  19    0.000330
# 1    2020-02-29                  23    0.000400
# 2    2020-03-31                1609    0.027978
# 3    2020-04-30                1303    0.022657
# 4    2020-05-31                 127    0.002208

# %%
#ข้อมูลโหมดการเดินาง
df_travel_mode['percentage_ทางน้ำ'] = df_travel_mode['ทางน้ำ']/df_travel_mode['ทางน้ำ'].sum()
df_travel_mode['percentage_ทางบก'] = df_travel_mode['ทางบก']/df_travel_mode['ทางบก'].sum()
df_travel_mode['percentage_ทางราง'] = df_travel_mode['ทางราง']/df_travel_mode['ทางราง'].sum()
df_travel_mode['percentage_ทางอากาศ'] = df_travel_mode['ทางอากาศ']/df_travel_mode['ทางอากาศ'].sum()
df_travel_mode['percentage_ทางถนน'] = df_travel_mode['ทางถนน']/df_travel_mode['ทางถนน'].sum()
df_travel_mode.head()
# Out:
# Mode       date       ทางน้ำ  ... percentage_ทางอากาศ percentage_ทางถนน
# 0    2020-01-31  8.26194e+06  ...            0.277768          0.107132
# 1    2020-02-29  6.99893e+06  ...            0.179576          0.097179
# 2    2020-03-31  2.55306e+06  ...           0.0915457          0.068959
# 3    2020-04-30  1.15716e+06  ...           0.0025394          0.029453
# 4    2020-05-31  1.50509e+06  ...           0.0062487          0.040546
#
# [5 rows x 11 columns]

# %%
plt.figure(figsize=(8, 8))
plt.plot(df_covid_patients['announce_date'],df_covid_patients['percentage'],'b',label = 'ผู้ป่วย')
plt.plot(df_travel_mode['date'],df_travel_mode['percentage_ทางน้ำ'],'r',label = 'ทางน้ำ')
plt.plot(df_travel_mode['date'],df_travel_mode['percentage_ทางบก'],'g',label = 'ทางบก')
plt.plot(df_travel_mode['date'],df_travel_mode['percentage_ทางราง'],'c',label = 'ทางราง')
plt.plot(df_travel_mode['date'],df_travel_mode['percentage_ทางอากาศ'],'m',label = 'ทางอากาศ')
plt.plot(df_travel_mode['date'],df_travel_mode['percentage_ทางถนน'],'y',label = 'ทางถนน')
plt.legend()
plt.xlabel("วันที่")
plt.ylabel("เปอร์เซ็น")
plt.title('กราฟเปรียบเทียบแนวโน้มผู้ป่วยและการเดินทางแต่ละแบบ')
# Out:
# [<matplotlib.lines.Line2D object at 0x7f0d97e5bc50>]
# Text(0.5, 1.0, 'กราฟเปรียบเทียบแนวโน้มผู้ป่วยและการเดินทางแต่ละแบบ')

# %% [markdown]
# ###ข้อที่ 3

# %%
data_covid_prvince_last6M = data_covid_prvince_day[data_covid_prvince_day['announce_date']>= datetime(2020, 11, 1)]
data_covid_prvince_last6M.head()
# Out:
#      announce_date province_of_onset  number_of_patients
# 3781    2020-11-01     กรุงเทพมหานคร                   1
# 3782    2020-11-01           นนทบุรี                   1
# 3783    2020-11-01     กรุงเทพมหานคร                   1
# 3784    2020-11-01     กรุงเทพมหานคร                   1
# 3785    2020-11-02       สมุทรปราการ                   1

# %%
data_covid_prvince_last6M_sum = data_covid_prvince_last6M.groupby('province_of_onset').sum()
data_covid_prvince_last6M_sum.head()
# Out:
#                    number_of_patients
# province_of_onset
# กระบี่                             58
# กรุงเทพมหานคร                   12779
# กาญจนบุรี                          94
# กาฬสินธุ์                          58
# กำแพงเพชร                          84

# %%
data_covid_prvince_last6M_sum.sort_values('number_of_patients',inplace=True,ascending=False)
data_covid_prvince_last6M_sum.reset_index(drop=True, inplace=True)
data_covid_prvince_last6M_sum.head()
# Out:
#    number_of_patients province_of_onset
# 0               17547         สมุทรสาคร
# 1               12779     กรุงเทพมหานคร
# 2                3244         เชียงใหม่
# 3                3138            ชลบุรี
# 4                1480          ปทุมธานี

# %%
data_covid_Top_prvince = data_covid_prvince_last6M_sum.iloc[0:10]
data_covid_Top_prvince
# Out:
#    number_of_patients province_of_onset
# 0               17547         สมุทรสาคร
# 1               12779     กรุงเทพมหานคร
# 2                3244         เชียงใหม่
# 3                3138            ชลบุรี
# 4                1480          ปทุมธานี
# 5                1302       สมุทรปราการ
# 6                1026           นนทบุรี
# 7                1022             ระยอง
# 8                 991   ประจวบคีรีขันธ์
# 9                 647            นครปฐม

# %%
plt.figure(figsize=(20, 8))
plt.bar(data_covid_Top_prvince['province_of_onset'],
        data_covid_Top_prvince['number_of_patients'],
        data = data_covid_Top_prvince)
plt.xlabel('จังหวัด')
plt.ylabel('จำนวนผู้ป่วยที่พบ (คน)')
plt.title('จำนวนผู้ป่วยที่ตรวจพบเชื้อ covid-19 ของจังหวัด top 10');

# %% [markdown]
# ###ข้อที่ 4

# %%
region = list()
for i in df_covid_prvince.iterrows():
  for j in df_region.iterrows():
    if i[1]['province_of_onset'] == j[1]['province']:
       region.append(j[1]['region'])
df_covid_prvince['region'] = region
df_covid_prvince.head()
# Out:
#   province_of_onset  number_of_patients              region
# 0            กระบี่                  78                 ใต้
# 1     กรุงเทพมหานคร               14611                กลาง
# 2         กาญจนบุรี                 103                กลาง
# 3         กาฬสินธุ์                  61  ตะวันออกเฉียงเหนือ
# 4         กำแพงเพชร                  84               เหนือ

# %%
df_region_of_patient = df_covid_prvince.groupby('region').sum()
df_region_of_patient
# Out:
#                     number_of_patients
# region
# กลาง                             40103
# ตะวันออก                          5678
# ตะวันออกเฉียงเหนือ                2412
# เหนือ                             5627
# ใต้                               3309

# %%
df_region_of_patient.sort_values('number_of_patients', ascending=False, inplace=True)
df_region_of_patient.head()
# Out:
#    number_of_patients              region
# 0               40103                กลาง
# 1                5678            ตะวันออก
# 3                5627               เหนือ
# 4                3309                 ใต้
# 2                2412  ตะวันออกเฉียงเหนือ

# %%
plt.figure(figsize=(10, 8))
plt.bar(df_region_of_patient['region'],
        df_region_of_patient['number_of_patients'],
        data = df_region_of_patient)
plt.xlabel('ภูมิภาค')
plt.ylabel('จำนวนผู้ป่วยที่พบ (คน)')
plt.title('จำนวนผู้ป่วยที่ตรวจพบเชื้อ covid-19 ของแต่ละภูมิภาค(การท่องเที่ยว)')
# Out:
# Text(0.5, 1.0, 'จำนวนผู้ป่วยที่ตรวจพบเชื้อ covid-19 ของแต่ละภูมิภาค(การท่องเที่ยว)')
